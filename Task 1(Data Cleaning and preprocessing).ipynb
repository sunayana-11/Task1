# %%
import numpy as np
import pandas as pd

# %%
sales=pd.read_csv(r"C:\Users\Sunayana Panigrahi\Downloads\archive (1)\Online Sales Data.csv")
sales
# Out:
#      Transaction ID        Date Product Category  \
# 0             10001  2024-01-01      Electronics
# 1             10002  2024-01-02  Home Appliances
# 2             10003  2024-01-03         Clothing
# 3             10004  2024-01-04            Books
# 4             10005  2024-01-05  Beauty Products
# ..              ...         ...              ...
# 235           10236  2024-08-23  Home Appliances
# 236           10237  2024-08-24         Clothing
# 237           10238  2024-08-25            Books
# 238           10239  2024-08-26  Beauty Products
# 239           10240  2024-08-27           Sports
#
#                                         Product Name  Units Sold  Unit Price  \
# 0                                      iPhone 14 Pro           2      999.99
# 1                                   Dyson V11 Vacuum           1      499.99
# 2                                   Levi's 501 Jeans           3       69.99
# ...

# %%
sales.isnull().sum()
# Out:
# Transaction ID      0
# Date                0
# Product Category    0
# Product Name        0
# Units Sold          0
# Unit Price          0
# Total Revenue       0
# Region              0
# Payment Method      0
# dtype: int64

# %%
sales.drop_duplicates()
# Out:
#      Transaction ID        Date Product Category  \
# 0             10001  2024-01-01      Electronics
# 1             10002  2024-01-02  Home Appliances
# 2             10003  2024-01-03         Clothing
# 3             10004  2024-01-04            Books
# 4             10005  2024-01-05  Beauty Products
# ..              ...         ...              ...
# 235           10236  2024-08-23  Home Appliances
# 236           10237  2024-08-24         Clothing
# 237           10238  2024-08-25            Books
# 238           10239  2024-08-26  Beauty Products
# 239           10240  2024-08-27           Sports
#
#                                         Product Name  Units Sold  Unit Price  \
# 0                                      iPhone 14 Pro           2      999.99
# 1                                   Dyson V11 Vacuum           1      499.99
# 2                                   Levi's 501 Jeans           3       69.99
# ...

# %%
#Finding unique values in the text formats
for i in sales.columns:
    print(i,':','\n',sales[i].unique(),'\n')
# Out:
# Transaction ID :
#  [10001 10002 10003 10004 10005 10006 10007 10008 10009 10010 10011 10012
#  10013 10014 10015 10016 10017 10018 10019 10020 10021 10022 10023 10024
#  10025 10026 10027 10028 10029 10030 10031 10032 10033 10034 10035 10036
#  10037 10038 10039 10040 10041 10042 10043 10044 10045 10046 10047 10048
#  10049 10050 10051 10052 10053 10054 10055 10056 10057 10058 10059 10060
#  10061 10062 10063 10064 10065 10066 10067 10068 10069 10070 10071 10072
#  10073 10074 10075 10076 10077 10078 10079 10080 10081 10082 10083 10084
#  10085 10086 10087 10088 10089 10090 10091 10092 10093 10094 10095 10096
#  10097 10098 10099 10100 10101 10102 10103 10104 10105 10106 10107 10108
#  10109 10110 10111 10112 10113 10114 10115 10116 10117 10118 10119 10120
#  10121 10122 10123 10124 10125 10126 10127 10128 10129 10130 10131 10132
#  10133 10134 10135 10136 10137 10138 10139 10140 10141 10142 10143 10144
#  10145 10146 10147 10148 10149 10150 10151 10152 10153 10154 10155 10156
# ...

# %%
#Convert date formats into consistent type
sales['Date'] = pd.to_datetime(sales['Date'], errors='coerce', dayfirst=True)
sales['Date'] = sales['Date'].dt.strftime('%d-%m-%Y')
sales
# Out:
#      Transaction ID        Date Product Category  \
# 0             10001  01-01-2024      Electronics
# 1             10002  01-02-2024  Home Appliances
# 2             10003  01-03-2024         Clothing
# 3             10004  01-04-2024            Books
# 4             10005  01-05-2024  Beauty Products
# ..              ...         ...              ...
# 235           10236         NaN  Home Appliances
# 236           10237         NaN         Clothing
# 237           10238         NaN            Books
# 238           10239         NaN  Beauty Products
# 239           10240         NaN           Sports
#
#                                         Product Name  Units Sold  Unit Price  \
# 0                                      iPhone 14 Pro           2      999.99
# 1                                   Dyson V11 Vacuum           1      499.99
# 2                                   Levi's 501 Jeans           3       69.99
# ...

# %%
#Convert columns to lower case
sales.columns = sales.columns.str.lower()
sales
# Out:
#      transaction id        date product category  \
# 0             10001  01-01-2024      Electronics
# 1             10002  01-02-2024  Home Appliances
# 2             10003  01-03-2024         Clothing
# 3             10004  01-04-2024            Books
# 4             10005  01-05-2024  Beauty Products
# ..              ...         ...              ...
# 235           10236         NaN  Home Appliances
# 236           10237         NaN         Clothing
# 237           10238         NaN            Books
# 238           10239         NaN  Beauty Products
# 239           10240         NaN           Sports
#
#                                         product name  units sold  unit price  \
# 0                                      iPhone 14 Pro           2      999.99
# 1                                   Dyson V11 Vacuum           1      499.99
# 2                                   Levi's 501 Jeans           3       69.99
# ...

# %%
#to remove spaces
sales.columns = sales.columns.str.replace(' ','_')
sales
# Out:
#      transaction_id        date product_category  \
# 0             10001  01-01-2024      Electronics
# 1             10002  01-02-2024  Home Appliances
# 2             10003  01-03-2024         Clothing
# 3             10004  01-04-2024            Books
# 4             10005  01-05-2024  Beauty Products
# ..              ...         ...              ...
# 235           10236         NaN  Home Appliances
# 236           10237         NaN         Clothing
# 237           10238         NaN            Books
# 238           10239         NaN  Beauty Products
# 239           10240         NaN           Sports
#
#                                         product_name  units_sold  unit_price  \
# 0                                      iPhone 14 Pro           2      999.99
# 1                                   Dyson V11 Vacuum           1      499.99
# 2                                   Levi's 501 Jeans           3       69.99
# ...

# %%
#Check datatypes
sales.dtypes
# Out:
# transaction_id        int64
# date                 object
# product_category     object
# product_name         object
# units_sold            int64
# unit_price          float64
# total_revenue       float64
# region               object
# payment_method       object
# dtype: object

# %%
#Convert Date from str to date
sales['date'] = pd.to_datetime(sales['date'], errors='coerce', dayfirst=True)
sales.dtypes
# Out:
# transaction_id               int64
# date                datetime64[ns]
# product_category            object
# product_name                object
# units_sold                   int64
# unit_price                 float64
# total_revenue              float64
# region                      object
# payment_method              object
# dtype: object
